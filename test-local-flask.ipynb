# %% [markdown]
# # Testes com Flask local

# %%
# !curl http://localhost:5000
# Out:
# Hello from Flask, by Insper DS! - 2023-06-17 13:34:23.674590

# %%
import requests

# %%
requests.get("http://localhost:5000").text
# Out:
# 'Hello from Flask, by Insper DS! - 2023-06-17 13:34:30.101174'

# %%
requests.get("http://localhost:5000/core").text
# Out:
# 'Vai Corinthians!! - 2023-06-17 11:55:11.312507'

# %%
requests.get("http://localhost:5000/mundialpalmeiras").text
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">\n<title>404 Not Found</title>\n<h1>Not Found</h1>\n<p>The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.</p>\n'

# %%
requests.get("http://localhost:5000/add/20/44").text
# Out:
# '64.0'

# %%
requests.get("http://localhost:5000/add/43/44.5").text
# Out:
# '87.5'

# %%
requests.get("http://localhost:5000/add/43/3e2").text
# Out:
# '343.0'

# %%
requests.get("http://localhost:5000/area?altura=10&largura=22&comprimento=9").text
# Out:
# '1980.0'

# %%
requests.get("http://localhost:5000/bitcoins").json()
# Out:
# {'btc': [{'amount': 1.938e-05,
#    'date': 1686976718,
#    'price': 127726.02,
#    'tid': 15251116,
#    'type': 'buy'},
#   {'amount': 6.2e-05,
#    'date': 1686976777,
#    'price': 127726.01999999,
#    'tid': 15251117,
#    'type': 'sell'},
#   {'amount': 3.767e-05,
#    'date': 1686976836,
#    'price': 127726.02,
#    'tid': 15251118,
#    'type': 'buy'},
#   {'amount': 6.076e-05,
#    'date': 1686976977,
#    'price': 127726.02,
#    'tid': 15251119,
#    'type': 'buy'},
#   {'amount': 1.55e-05,
#    'date': 1686977047,
#    'price': 127726.01999999,
#    'tid': 15251120,
#    'type': 'sell'},
#   {'amount': 1.944e-05,
#    'date': 1686977076,
#    'price': 127726.02,
#    'tid': 15251121,
#    'type': 'buy'},
#   {'amount': 1.859e-05,
#    'date': 1686977087,
#    'price': 127726.01999999,
#    'tid': 15251122,
#    'type': 'sell'},
#   {'amount': 2.937e-05,
#    'date': 1686977258,
#    'price': 127791.92,
#    'tid': 15251123,
#    'type': 'buy'},
# ...

# %%
requests.get("http://localhost:5000/ethereum").json()
# Out:
# {'eth': [{'amount': 0.42017271,
#    'date': 1686927668,
#    'price': 8138.16122519,
#    'tid': 5303394,
#    'type': 'sell'},
#   {'amount': 0.149,
#    'date': 1686927769,
#    'price': 8127.56158983,
#    'tid': 5303395,
#    'type': 'sell'},
#   {'amount': 0.051,
#    'date': 1686927769,
#    'price': 8123.51701497,
#    'tid': 5303396,
#    'type': 'sell'},
#   {'amount': 0.1275,
#    'date': 1686927820,
#    'price': 8118.09490555,
#    'tid': 5303397,
#    'type': 'sell'},
#   {'amount': 0.0163,
#    'date': 1686927832,
#    'price': 8118.09490555,
#    'tid': 5303398,
#    'type': 'sell'},
#   {'amount': 0.1117,
#    'date': 1686927832,
#    'price': 8118.0945773,
#    'tid': 5303399,
#    'type': 'sell'},
#   {'amount': 0.01230516,
#    'date': 1686927853,
#    'price': 8126.66999999,
#    'tid': 5303400,
#    'type': 'buy'},
#   {'amount': 0.00020096,
#    'date': 1686927965,
#    'price': 8109.73074418,
#    'tid': 5303401,
#    'type': 'buy'},
# ...

# %%
requests.get("http://localhost:5000/weather/34.5/45.5").json()
# Out:
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 34.5, 'lon': 45.5},
#  'dt': 1687020645,
#  'id': 91823,
#  'main': {'feels_like': 304.05,
#   'grnd_level': 948,
#   'humidity': 14,
#   'pressure': 1002,
#   'sea_level': 1002,
#   'temp': 306.43,
#   'temp_max': 306.43,
#   'temp_min': 306.43},
#  'name': 'Aḩmad Ţāhir',
#  'sys': {'country': 'IQ', 'sunrise': 1686966307, 'sunset': 1687018352},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#    'icon': '01n',
#    'id': 800,
#    'main': 'Clear'}],
#  'wind': {'deg': 311, 'gust': 10.11, 'speed': 5.15}}
